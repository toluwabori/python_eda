# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
df_crunchbase  = pd.read_csv('unicorns.csv')

# %%
df_crunchbase
# Out:
#                   Updated at     Company  \
# 0     10/31/2022, 2:37:05 AM       Esusu
# 1     10/31/2022, 2:37:05 AM  Fever Labs
# 2     10/31/2022, 2:37:04 AM       Minio
# 3     10/31/2022, 2:37:04 AM   Darwinbox
# 4     10/31/2022, 2:37:04 AM     Pentera
# ...                      ...         ...
# 1194  10/31/2022, 2:32:42 AM    Fanatics
# 1195  10/31/2022, 2:32:38 AM      SpaceX
# 1196  10/31/2022, 2:33:10 AM  Vice Media
# 1197  10/31/2022, 2:33:05 AM      Klarna
# 1198  10/31/2022, 2:35:27 AM      Veepee
#
#                                          Crunchbase Url  \
# 0              https://www.cbinsights.com/company/esusu
# 1         https://www.cbinsights.com/company/fever-labs
# 2              https://www.cbinsights.com/company/minio
# 3          https://www.cbinsights.com/company/darwinbox
# 4             https://www.cbinsights.com/company/pcysys
# ...                                                 ...
# 1194        https://www.cbinsights.com/company/fanatics
# ...

# %%
df_crunchbase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Updated at                  1199 non-null   object
#  1   Company                     1199 non-null   object
#  2   Crunchbase Url              1199 non-null   object
#  3   Last Valuation (Billion $)  1199 non-null   float64
#  4   Date Joined                 1199 non-null   object
#  5   Year Joined                 1199 non-null   int64
#  6   City                        1181 non-null   object
#  7   Country                     1199 non-null   object
#  8   Industry                    1199 non-null   object
#  9   Investors                   1199 non-null   object
#  10  Company Website             0 non-null      float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 103.2+ KB

# %%
df_crunchbase = df_crunchbase.drop(columns=['Updated at','Crunchbase Url','Date Joined','Investors','Company Website'])

# %%
df_crunchbase.dropna(inplace=True)

# %%
df_crunchbase['Year Joined']= df_crunchbase['Year Joined'].astype(object)

# %%
df_crunchbase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1181 entries, 0 to 1198
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Company                     1181 non-null   object
#  1   Last Valuation (Billion $)  1181 non-null   float64
#  2   Year Joined                 1181 non-null   object
#  3   City                        1181 non-null   object
#  4   Country                     1181 non-null   object
#  5   Industry                    1181 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 64.6+ KB

# %%
df_crunchbase
# Out:
#          Company  Last Valuation (Billion $) Year Joined  \
# 0          Esusu                        1.00        2022
# 1     Fever Labs                        1.00        2022
# 2          Minio                        1.00        2022
# 3      Darwinbox                        1.00        2022
# 4        Pentera                        1.00        2022
# ...          ...                         ...         ...
# 1194    Fanatics                       27.00        2012
# 1195      SpaceX                      127.00        2012
# 1196  Vice Media                        5.70        2011
# 1197      Klarna                        6.70        2011
# 1198      Veepee                        1.38        2007
#
#                        City        Country                         Industry
# 0                  New York  United States                          Fintech
# 1                  New York  United States     Internet software & services
# ...

# %%
df_crunchbase['Year Joined'].value_counts()
# Out:
# 2021    515
# 2022    245
# 2020    105
# 2019    101
# 2018     97
# 2017     41
# 2015     34
# 2016     21
# 2014     12
# 2012      4
# 2013      3
# 2011      2
# 2007      1
# Name: Year Joined, dtype: int64

# %%
df_crunchbase['Year Joined'].value_counts().plot(kind = 'barh')
plt.xlabel('counts of companies')
plt.ylabel('year joined');

# %%
#the list will be summarized to the largest 10
df_crunchbase['City'].value_counts().nlargest(10)
# Out:
# San Francisco    169
# New York         115
# Beijing           62
# Shanghai          44
# London            37
# Bengaluru         31
# Boston            22
# Palo Alto         20
# Shenzhen          20
# Berlin            20
# Name: City, dtype: int64

# %%
df_crunchbase['City'].value_counts().nlargest(10).plot(kind='barh')
plt.xlabel('counts of companies')
plt.ylabel('CITY');

# %%
df_crunchbase.Industry.value_counts()
# Out:
# Fintech                                245
# Internet software & services           229
# E-commerce & direct-to-consumer        105
# Health                                  95
# Artificial intelligence                 73
# Supply chain, logistics, & delivery     67
# Other                                   64
# Cybersecurity                           56
# Data management & analytics             45
# Hardware                                38
# Mobile & telecommunications             38
# Auto & transportation                   37
# Edtech                                  32
# Consumer & retail                       27
# Travel                                  14
# Artificial Intelligence                 11
# Cybersecurity                            2
# Auto & transportation                    1
# Artificial intelligence                  1
# Consumer & retail                        1
# Name: Industry, dtype: int64

# %%
df_crunchbase.Industry.value_counts().plot(kind='barh')
plt.xlabel('counts of companies')
plt.ylabel('INDUSTRY');

# %%
df_crunchbase.groupby('Country').sum().nlargest(5,columns = 'Last Valuation (Billion $)').plot(kind = 'barh');

# %%
df_crunchbase.groupby('Industry').mean().nlargest(5,columns='Last Valuation (Billion $)').plot(kind='line',rot = 90);
